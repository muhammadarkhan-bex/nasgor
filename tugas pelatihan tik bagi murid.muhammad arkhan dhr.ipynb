# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadarkhan-bex/nasgor/blob/main/Selamat_Datang_di_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bagian Baru

# %%
print("=========PROGRAM KASIR KANTIN==========")
print("Oleh Muhammad Arkhan DHR")
print("tugas pelatihan tik bagi murid")

import datetime
saat_ini = datetime.datetime.now()
print(saat_ini)
print("=======================================")

pembeli = input("Masukan Nama Pembeli: ")
print("Nama Pembeli: ",pembeli)

total1 = 0
jenis1 = ""
porsi = 0
gelas = 0

def fungsimakanan():
  global total1
  global porsi1
  global jenis1

  print("\n=========Menu Makanan=============")
  print("1. Nasi Goreng - Rp 15.000")
  print("2. Bakso - Rp 10.000")
  print("3. Mie Ayam - Rp 13.000")

  nomor = int(input("Masukan Pilihan: "))
  porsi = int(input("Berapa Porsi: "))

  if nomor == 1:
    total1 = porsi*15000
    print(porsi, "Porsi Nasi Goreng = Rp", total1)
    jenis1 = ("Nasi Goreng")
  elif nomor == 2:
    total1 = porsi*10000
    print(porsi, "Porsi Bakso = Rp", total1)
    jenis1 = ("soto")
  elif nomor == 3:
    total1 = porsi*13000
    print(porsi, "Porsi Mie Ayam = Rp", total1)
    jenis1 = ("Mie Ayam")
  else:
      print("Pilihan Tidak Tersedia, Silakan masukan lagi!")
      fungsimakanan()

fungsimakanan()
total2 = 0
jenis2=""

def fungsiminuman():
      global total2
      global jenis2
      global gelas

      print("\n========Menu Minuman===========")
      print("1. Es teh - Rp 2.000")
      print("2. Es jeruk - Rp 3.000")
      print("3. kopi - Rp 4.000")
      nomor = int(input("Masukan Pilihan: "))
      gelas = int(input("Berapa Gelas: "))

      if nomor == 1:
        total2 = gelas * 2000
        print(gelas, "Es Teh = Rp", total2)
        jenis2 = ("Gelas Es Teh")
      elif nomor == 2:
        total2 = gelas * 35000
        print(gelas, "Es Jeruk = Rp", total2)
        jenis2 = ("Gelas Es Jeruk")
      elif nomor == 3:
        total2 = gelas * 4000
        print(gelas, "Kopi = RP", total2)
        jenis2 = ("Gelas Kopi")
      else:
        print("Pilihan tidak ada, silakan masukan lagi!")
        fungsiminuman()

fungsiminuman()
totalsemua = 0
totalsemua = total1 + total2

print("\nTotal Pembayaran: Rp", totalsemua)
uang = int(input("Uang Tunai Pembeli: Rp "))
kembalian = int(uang - totalsemua)
print("kembalian: ", kembalian)

print("\n============================")
print("========STRUK BELI===========")
print("\n============================")
print("Nama     : ", pembeli)
import datetime
saat_ini = datetime.datetime.now()
print("Tanggal   : ", saat_ini)
print("Beli      : ", porsi, jenis1,"-", total1)
print("          : ", gelas, jenis2, "-", total2)
print("Tagihan   : Rp.", totalsemua)
print("Uang      : Rp.", uang)
print("kembalian : Rp.", kembalian)
print("\n============================")
print("\n============================")
# Out:
# =========PROGRAM KASIR KANTIN==========
# Oleh Muhammad Arkhan DHR
# tugas pelatihan tik bagi murid
# 2025-11-03 10:06:16.311170
# ...
# Masukan Nama Pembeli: ibe
# Nama Pembeli:  ibe
#
# =========Menu Makanan=============
# 1. Nasi Goreng - Rp 15.000
# 2. Bakso - Rp 10.000
# 3. Mie Ayam - Rp 13.000
# Masukan Pilihan: 3
# Berapa Porsi: 2
# 2 Porsi Mie Ayam = Rp 26000
#
# ========Menu Minuman===========
# 1. Es teh - Rp 2.000
# 2. Es jeruk - Rp 3.000
# 3. kopi - Rp 4.000
# Masukan Pilihan: 2
# Berapa Gelas: 2
# 2 Es Jeruk = Rp 70000
#
# Total Pembayaran: Rp 96000
# Uang Tunai Pembeli: Rp 100000
# kembalian:  4000
#
# ...
# ========STRUK BELI===========
#
# ...
# Nama     :  ibe
# Tanggal   :  2025-11-03 10:07:02.745748
# Beli      :  0 Mie Ayam - 26000
#           :  2 Gelas Es Jeruk - 70000
# Tagihan   : Rp. 96000
# Uang      : Rp. 100000
# kembalian : Rp. 4000
#
# ...
#
# ...
